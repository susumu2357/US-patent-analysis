# %%
import pandas as pd

# %%
xml = pd.read_table("../data/app_bib_2017/ipab20170105.xml", header=None)

# %%
xml.head()
# Out:
#                                                    0
# 0             <?xml version="1.0" encoding="UTF-8"?>
# 1  <!DOCTYPE us-patent-application SYSTEM "us-pat...
# 2  <us-patent-application lang="EN" dtd-version="...
# 3  <us-bibliographic-data-application lang="EN" c...
# 4                            <publication-reference>

# %%
xml[0].str.contains('<publication-reference>')
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4           True
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 1565418    False
# 1565419    False
# 1565420    False
# 1565421    False
# 1565422    False
# 1565423    False
# 1565424    False
# 1565425    False
# 1565426    False
# 1565427    False
# 1565428    False
# 1565429    False
# 1565430    False
# 1565431    False
# 1565432    False
# 1565433    False
# 1565434    False
# 1565435    False
# 1565436    False
# 1565437    False
# 1565438    False
# ...

# %%
mask = xml[0].str.contains('<publication-reference>')

# %%
add = [False, False, False]

# %%
add_df = pd.Series(add)

# %%
add_df
# Out:
# 0    False
# 1    False
# 2    False
# dtype: bool

# %%
mask_pgpub = pd.concat([add_df, mask])

# %%
mask_pgpub
# Out:
# 0          False
# 1          False
# 2          False
# 0          False
# 1          False
# 2          False
# 3          False
# 4           True
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
#            ...
# 1565418    False
# 1565419    False
# 1565420    False
# 1565421    False
# 1565422    False
# 1565423    False
# 1565424    False
# 1565425    False
# 1565426    False
# 1565427    False
# 1565428    False
# 1565429    False
# 1565430    False
# 1565431    False
# 1565432    False
# 1565433    False
# 1565434    False
# 1565435    False
# 1565436    False
# 1565437    False
# 1565438    False
# ...

# %%
mask_pgpub = mask_pgpub.reset_index(drop = True)

# %%
mask_pgpub
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7           True
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 1565421    False
# 1565422    False
# 1565423    False
# 1565424    False
# 1565425    False
# 1565426    False
# 1565427    False
# 1565428    False
# 1565429    False
# 1565430    False
# 1565431    False
# 1565432    False
# 1565433    False
# 1565434    False
# 1565435    False
# 1565436    False
# 1565437    False
# 1565438    False
# 1565439    False
# 1565440    False
# 1565441    False
# ...

# %%
xml_pgpub = xml[0].where(mask_pgpub)

# %%
xml_pgpub
# Out:
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7          <doc-number>20170000001</doc-number>
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# ...

# %%
xml_pgpub = xml_pgpub.dropna(how = all)

# %%
xml_pgpub
# Out:
# 7          <doc-number>20170000001</doc-number>
# 125        <doc-number>20170000002</doc-number>
# 400        <doc-number>20170000003</doc-number>
# 642        <doc-number>20170000004</doc-number>
# 800        <doc-number>20170000005</doc-number>
# 978        <doc-number>20170000006</doc-number>
# 1167       <doc-number>20170000007</doc-number>
# 1356       <doc-number>20170000008</doc-number>
# 1556       <doc-number>20170000009</doc-number>
# 1745       <doc-number>20170000010</doc-number>
# 1945       <doc-number>20170000011</doc-number>
# 2153       <doc-number>20170000012</doc-number>
# 2283       <doc-number>20170000013</doc-number>
# 2453       <doc-number>20170000014</doc-number>
# 2623       <doc-number>20170000015</doc-number>
# 2812       <doc-number>20170000016</doc-number>
# 2949       <doc-number>20170000017</doc-number>
# 3086       <doc-number>20170000018</doc-number>
# 3202       <doc-number>20170000019</doc-number>
# 3350       <doc-number>20170000020</doc-number>
# ...

# %%
xml[0].str.contains('<application-reference appl-type="utility">').head(50)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# Name: 0, dtype: bool

# %%
mask_app = pd.concat([add_df, xml[0].str.contains('<application-reference appl-type="utility">')])

# %%
mask_app
# Out:
# 0          False
# 1          False
# 2          False
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12          True
# 13         False
# 14         False
# 15         False
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
#            ...
# 1565418    False
# 1565419    False
# 1565420    False
# 1565421    False
# 1565422    False
# 1565423    False
# 1565424    False
# 1565425    False
# 1565426    False
# 1565427    False
# 1565428    False
# 1565429    False
# 1565430    False
# 1565431    False
# 1565432    False
# 1565433    False
# 1565434    False
# 1565435    False
# 1565436    False
# 1565437    False
# 1565438    False
# ...

# %%
mask_app = mask_app.reset_index(drop = True)

# %%
mask_app
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
# 5          False
# 6          False
# 7          False
# 8          False
# 9          False
# 10         False
# 11         False
# 12         False
# 13         False
# 14         False
# 15          True
# 16         False
# 17         False
# 18         False
# 19         False
# 20         False
# 21         False
# 22         False
# 23         False
# 24         False
# 25         False
# 26         False
# 27         False
# 28         False
# 29         False
#            ...
# 1565421    False
# 1565422    False
# 1565423    False
# 1565424    False
# 1565425    False
# 1565426    False
# 1565427    False
# 1565428    False
# 1565429    False
# 1565430    False
# 1565431    False
# 1565432    False
# 1565433    False
# 1565434    False
# 1565435    False
# 1565436    False
# 1565437    False
# 1565438    False
# 1565439    False
# 1565440    False
# 1565441    False
# ...

# %%
xml_app = xml[0].where(mask_app)

# %%
xml_app
# Out:
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                                       NaN
# 15         <doc-number>14789882</doc-number>
# 16                                       NaN
# 17                                       NaN
# 18                                       NaN
# 19                                       NaN
# 20                                       NaN
# ...

# %%
xml_app = xml_app.dropna(how = all)

# %%
xml_app
# Out:
# 15         <doc-number>14789882</doc-number>
# 133        <doc-number>14755945</doc-number>
# 408        <doc-number>14755919</doc-number>
# 650        <doc-number>14755034</doc-number>
# 808        <doc-number>14788318</doc-number>
# 986        <doc-number>14788216</doc-number>
# 1175       <doc-number>14755816</doc-number>
# 1364       <doc-number>14755741</doc-number>
# 1564       <doc-number>14755013</doc-number>
# 1753       <doc-number>14788246</doc-number>
# 1953       <doc-number>15265874</doc-number>
# 2161       <doc-number>15266111</doc-number>
# 2291       <doc-number>14788087</doc-number>
# 2461       <doc-number>14754811</doc-number>
# 2631       <doc-number>14755890</doc-number>
# 2820       <doc-number>14755045</doc-number>
# 2957       <doc-number>14788287</doc-number>
# 3094       <doc-number>14755409</doc-number>
# 3210       <doc-number>14755111</doc-number>
# 3358       <doc-number>14755552</doc-number>
# 3485       <doc-number>15145531</doc-number>
# ...

# %%
xml_pgpub_num = xml_pgpub.str[12:23]

# %%
type(xml_pgpub_num.index.values.tolist())
# Out:
# list

# %%
xml_pgpub_df = pd.DataFrame(xml_pgpub_num)

# %%
xml_pgpub_df
# Out:
#                    0
# 7        20170000001
# 125      20170000002
# 400      20170000003
# 642      20170000004
# 800      20170000005
# 978      20170000006
# 1167     20170000007
# 1356     20170000008
# 1556     20170000009
# 1745     20170000010
# 1945     20170000011
# 2153     20170000012
# 2283     20170000013
# 2453     20170000014
# 2623     20170000015
# 2812     20170000016
# 2949     20170000017
# 3086     20170000018
# 3202     20170000019
# 3350     20170000020
# 3477     20170000021
# 3786     20170000022
# 3947     20170000023
# 4147     20170000024
# 4317     20170000025
# 4489     20170000026
# 4794     20170000027
# 4887     20170000028
# 5076     20170000029
# 5278     20170000030
# ...              ...
# 1560715  20170006727
# 1560926  20170006728
# 1561122  20170006729
# 1561282  20170006730
# 1561445  20170006731
# 1561635  20170006732
# 1561804  20170006733
# 1561980  20170006734
# 1562121  20170006735
# 1562406  20170006736
# 1562637  20170006737
# ...

# %%
xml_pgpub_df[1] = xml_pgpub_num.index.values.tolist()

# %%
xml_pgpub_df = xml_pgpub_df.reset_index(drop = True)

# %%
xml_pgpub_df
# Out:
#                 0        1
# 0     20170000001        7
# 1     20170000002      125
# 2     20170000003      400
# 3     20170000004      642
# 4     20170000005      800
# 5     20170000006      978
# 6     20170000007     1167
# 7     20170000008     1356
# 8     20170000009     1556
# 9     20170000010     1745
# 10    20170000011     1945
# 11    20170000012     2153
# 12    20170000013     2283
# 13    20170000014     2453
# 14    20170000015     2623
# 15    20170000016     2812
# 16    20170000017     2949
# 17    20170000018     3086
# 18    20170000019     3202
# 19    20170000020     3350
# 20    20170000021     3477
# 21    20170000022     3786
# 22    20170000023     3947
# 23    20170000024     4147
# 24    20170000025     4317
# 25    20170000026     4489
# 26    20170000027     4794
# 27    20170000028     4887
# 28    20170000029     5076
# 29    20170000030     5278
# ...           ...      ...
# 6725  20170006727  1560715
# 6726  20170006728  1560926
# ...

# %%
xml_app_num = xml_app.str[12:20]

# %%
xml_app_df = pd.DataFrame(xml_app_num)

# %%
xml_app_df
# Out:
#                 0
# 15       14789882
# 133      14755945
# 408      14755919
# 650      14755034
# 808      14788318
# 986      14788216
# 1175     14755816
# 1364     14755741
# 1564     14755013
# 1753     14788246
# 1953     15265874
# 2161     15266111
# 2291     14788087
# 2461     14754811
# 2631     14755890
# 2820     14755045
# 2957     14788287
# 3094     14755409
# 3210     14755111
# 3358     14755552
# 3485     15145531
# 3794     15190652
# 3955     15232839
# 4155     14790906
# 4325     15258406
# 4497     15199032
# 4802     14545890
# 4895     15192631
# 5084     15269151
# 5286     15113598
# ...           ...
# 1558041  15122171
# 1558231  15168533
# 1558430  15264771
# 1558769  14290834
# 1558977  15113653
# 1559169  15134680
# 1559318  14790285
# 1559411  15176211
# 1559627  15200199
# 1559880  15197012
# 1560043  15196330
# 1560334  14975689
# 1560548  15109717
# 1560723  15192295
# 1560934  14806192
# 1561130  15188482
# 1561290  15114217
# 1561453  15104007
# ...

# %%
xml_app_df[1] = xml_app_num.index.values.tolist()

# %%
xml_app_df
# Out:
#                 0        1
# 15       14789882       15
# 133      14755945      133
# 408      14755919      408
# 650      14755034      650
# 808      14788318      808
# 986      14788216      986
# 1175     14755816     1175
# 1364     14755741     1364
# 1564     14755013     1564
# 1753     14788246     1753
# 1953     15265874     1953
# 2161     15266111     2161
# 2291     14788087     2291
# 2461     14754811     2461
# 2631     14755890     2631
# 2820     14755045     2820
# 2957     14788287     2957
# 3094     14755409     3094
# 3210     14755111     3210
# 3358     14755552     3358
# 3485     15145531     3485
# 3794     15190652     3794
# 3955     15232839     3955
# 4155     14790906     4155
# 4325     15258406     4325
# 4497     15199032     4497
# 4802     14545890     4802
# 4895     15192631     4895
# 5084     15269151     5084
# 5286     15113598     5286
# ...           ...      ...
# 1558041  15122171  1558041
# 1558231  15168533  1558231
# ...

# %%
type(xml_app_df[1][15])
# Out:
# numpy.int64

# %%
xml_app_df[1] = xml_app_df[1] -8

# %%
xml_app_df
# Out:
#                 0        1
# 15       14789882        7
# 133      14755945      125
# 408      14755919      400
# 650      14755034      642
# 808      14788318      800
# 986      14788216      978
# 1175     14755816     1167
# 1364     14755741     1356
# 1564     14755013     1556
# 1753     14788246     1745
# 1953     15265874     1945
# 2161     15266111     2153
# 2291     14788087     2283
# 2461     14754811     2453
# 2631     14755890     2623
# 2820     14755045     2812
# 2957     14788287     2949
# 3094     14755409     3086
# 3210     14755111     3202
# 3358     14755552     3350
# 3485     15145531     3477
# 3794     15190652     3786
# 3955     15232839     3947
# 4155     14790906     4147
# 4325     15258406     4317
# 4497     15199032     4489
# 4802     14545890     4794
# 4895     15192631     4887
# 5084     15269151     5076
# 5286     15113598     5278
# ...           ...      ...
# 1558041  15122171  1558033
# 1558231  15168533  1558223
# ...

# %%
app_pgpub_df = pd.merge(xml_app_df, xml_pgpub_df, on = 1)

# %%
app_pgpub_df
# Out:
#            0_x        1          0_y
# 0     14789882        7  20170000001
# 1     14755945      125  20170000002
# 2     14755919      400  20170000003
# 3     14755034      642  20170000004
# 4     14788318      800  20170000005
# 5     14788216      978  20170000006
# 6     14755816     1167  20170000007
# 7     14755741     1356  20170000008
# 8     14755013     1556  20170000009
# 9     14788246     1745  20170000010
# 10    15265874     1945  20170000011
# 11    15266111     2153  20170000012
# 12    14788087     2283  20170000013
# 13    14754811     2453  20170000014
# 14    14755890     2623  20170000015
# 15    14755045     2812  20170000016
# 16    14788287     2949  20170000017
# 17    14755409     3086  20170000018
# 18    14755111     3202  20170000019
# 19    14755552     3350  20170000020
# 20    15145531     3477  20170000021
# 21    15190652     3786  20170000022
# 22    15232839     3947  20170000023
# 23    14790906     4147  20170000024
# ...

# %%
app_pgpub_df = app_pgpub_df.rename(columns={'0_x': 'app_num', '0_y': 'pgpub_num'})

# %%
app_pgpub_df
# Out:
#        app_num        1    pgpub_num
# 0     14789882        7  20170000001
# 1     14755945      125  20170000002
# 2     14755919      400  20170000003
# 3     14755034      642  20170000004
# 4     14788318      800  20170000005
# 5     14788216      978  20170000006
# 6     14755816     1167  20170000007
# 7     14755741     1356  20170000008
# 8     14755013     1556  20170000009
# 9     14788246     1745  20170000010
# 10    15265874     1945  20170000011
# 11    15266111     2153  20170000012
# 12    14788087     2283  20170000013
# 13    14754811     2453  20170000014
# 14    14755890     2623  20170000015
# 15    14755045     2812  20170000016
# 16    14788287     2949  20170000017
# 17    14755409     3086  20170000018
# 18    14755111     3202  20170000019
# 19    14755552     3350  20170000020
# 20    15145531     3477  20170000021
# 21    15190652     3786  20170000022
# 22    15232839     3947  20170000023
# 23    14790906     4147  20170000024
# ...

# %%
app_pgpub_df.to_csv('../data/app2017_pgpub_correspondence.csv')
